# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot ([1,4,5], [3,2,7])
plt.show ()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace (-5, 5, 100)
y = np.sin (x)
plt.plot (x, y)
plt.show ()

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *
abscisse = np.linspace (0,7,100)
ordonnee = [2*sin(x) + x for x in abscisse]
plt.plot (abscisse, ordonnee)
plt.grid() # affiche une grille supplementaire sur le systeme de coordonnee
plt.show ()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,7,100)
y = 2 * np.sin(x) + x
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3,4,5]
y = [7,11,9,3,6]
largeur = 0.5
plt.bar(x, y, largeur)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1, 2, 3, 4, 5, 6]
y = [3, 2.7, 3.5, 3, 3, 4]
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1, 2, 3, 4, 5, 6]
y = [3, 2.7, 3.5, 3, 3, 4]
plt.scatter(x, y)
plt.plot(x, y)
plt.show()
